# %% [markdown]
# # RANDOM FOREST-(BULLISH MARKET CYCLE)
# This script uses Random Forest to predict stock price in a Bullish Market Cycle

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score, learning_curve
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import yfinance as yf

# %%
# Fetch data from Yahoo Finance
data = yf.download('^FTSE', start='2009-01-01', end='2015-06-30')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Drop NA values
data.dropna(inplace=True)

# %%
# Specify the feature names and target variable
feature_names = ['Open', 'High', 'Low']
target = 'Close'

# %%
X = data[feature_names]
y = data[target]

# %%
# Split the dataset into training and testing sets
train_size = int(0.80 * y.shape[0])
X_train = X[:train_size]
y_train = y[:train_size]
X_test = X[train_size:]
y_test = y[train_size:]

# %%
# Initialize and train the model with default parameters
rf_model = RandomForestRegressor()  # Using default parameters
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# Make predictions on the testing set
y_pred = rf_model.predict(X_test)

# %%
# Plot the predictions
y_pred_series = pd.Series(y_pred, index=y_test.index)
y_pred_series.plot()
plt.ylabel("Predicted 5 Day Close Price Change Percent")
plt.show()

# %%
# Plot the actual and predicted prices
plt.figure(figsize=(10,5))
plt.plot(y_test.index, y_test, color='blue', label='Actual FTSE Stock Price')
plt.plot(y_test.index, y_pred, color='red', label='Predicted FTSE Stock Price')
plt.title('FTSE Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('FTSE Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# # EVALUATION METRICS
# This metrics are used to evaluate the performance of the models compared. Cross validation is specifically included for more robust measure in comparing the various models performance.

# %%
# Cross-validation
cv_scores = cross_val_score(rf_model, X, y, cv=5)
print(f"Cross-validation scores: {cv_scores}")
print(f"Mean cross-validation score: {np.mean(cv_scores)}")
# Out:
# Cross-validation scores: [0.38328753 0.99098134 0.97898299 0.98772726 0.8390662 ]
# Mean cross-validation score: 0.8360090636272419

# %%
# Compute the mean squared error
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 4825.557432279649

# %%
# Root mean square error
rmse = np.sqrt(mse)
print(f"Root Mean Squared Error: {rmse}")
# Out:
# Root Mean Squared Error: 69.46623231671377

# %%
# Mean absolute percentage error
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
print(f"Mean Absolute Percentage Error: {mape}%")
# Out:
# Mean Absolute Percentage Error: 0.6110230698242718%
